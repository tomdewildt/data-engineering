# %%
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import window, col
from pyspark.sql.types import StructType, StructField, LongType, StringType, DoubleType
from time import sleep

# %%
spark_conf = SparkConf()
spark_conf.setMaster("spark://master:7077")
spark_conf.setAppName("Lab7_8")
spark_conf.set("spark.driver.memory", "2g")
spark_conf.set("spark.executor.cores", "1")
spark_conf.set("spark.driver.cores", "1")

# Create the spark session, which is the entry point to Spark SQL engine.
spark = SparkSession.builder.config(conf=spark_conf).getOrCreate()

# %%
# Read the whole dataset as a batch
static = spark.read.json("../data/activity")

data_schema = static.schema

# %%
# Read the dataset as a stream
sdf = spark.readStream.schema(data_schema).option("maxFilesPerTrigger", 1).json("../data/activity")

# %%
historical_agg = static.groupBy("gt", "model").avg()

# %%
# Combine the histotical dataset and the streaming data set
device_model_stats = sdf.drop("Arrival_Time", "Creation_Time", "Index").cube("gt", "model").avg().join(historical_agg, ["gt", "model"]).writeStream.queryName("device_counts").format("memory").outputMode("complete").start()

# %%
for x in range(10):
    spark.sql("SELECT * FROM device_counts").show()
    sleep(10)
# Out:
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# | gt|model|avg(x)|avg(y)|avg(z)|avg(Arrival_Time)|avg(Creation_Time)|avg(Index)|avg(x)|avg(y)|avg(z)|
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
#
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# | gt|model|avg(x)|avg(y)|avg(z)|avg(Arrival_Time)|avg(Creation_Time)|avg(Index)|avg(x)|avg(y)|avg(z)|
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
#
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# | gt|model|avg(x)|avg(y)|avg(z)|avg(Arrival_Time)|avg(Creation_Time)|avg(Index)|avg(x)|avg(y)|avg(z)|
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
#
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# | gt|model|avg(x)|avg(y)|avg(z)|avg(Arrival_Time)|avg(Creation_Time)|avg(Index)|avg(x)|avg(y)|avg(z)|
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
# +---+-----+------+------+------+-----------------+------------------+----------+------+------+------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4| 0.02351254447093367|-0.01304747996973...|-0.08360475809007034|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|0.001970352086338262| 7.48966684595554E-5|-0.00149828380428...|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4| 0.02810379107150039|-0.03570080351911377| 0.12203047970606438|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-4.92132825379805...|3.757376157445775...|-4.42863346250720...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.00989804137384...|4.133303473120169E-4|-2.86960196767412...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00302501221506...|-0.00410754501410...| 0.00596145206704953|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02623301318863349|-0.01385931765291...|-0.09395009728019485|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4| 0.02096106490343163|-0.00915222693840...|-0.08538726699652678|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00371092404649...|0.003353258755646498|0.001107451361787122|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.025383337512333733|-0.03625807633323724|   0.127126943458572|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-4.84874225480320...|3.237740430277434E-4|-4.65213713798297...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.19865608911238...|4.070066943871057E-4|1.027885098598906...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00601179783148...|-7.22352747272203...|0.003847526633724182|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02442588571617778|-0.01150252324103...|-0.09947070802664441|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.022510255124868785|-0.00898604823548...|-0.08336229972395504|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00317765395921...|0.003289352996140...|0.002783577999142...|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.024677638188492126|-0.03637329947153841| 0.12758820974660406|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.02209146083024...| 3.79996281616075E-4|-2.52092116718567...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.85281971657784...|4.911896808133751E-4|3.596050619546675...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00551275851715...|-6.49222625233698...|0.005846553661280072|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02538044852097...|-0.01115630564901936| -0.0984615561306473|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.022510255124868785|-0.00898604823548...|-0.08336229972395504|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00317765395921...|0.003289352996140...|0.002783577999142...|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.024677638188492126|-0.03637329947153841| 0.12758820974660406|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.02209146083024...| 3.79996281616075E-4|-2.52092116718567...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.85281971657784...|4.911896808133751E-4|3.596050619546675...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00551275851715...|-6.49222625233698...|0.005846553661280072|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02538044852097...|-0.01115630564901936| -0.0984615561306473|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.022510255124868785|-0.00898604823548...|-0.08336229972395504|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00317765395921...|0.003289352996140...|0.002783577999142...|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.024677638188492126|-0.03637329947153841| 0.12758820974660406|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.02209146083024...| 3.79996281616075E-4|-2.52092116718567...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.85281971657784...|4.911896808133751E-4|3.596050619546675...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00551275851715...|-6.49222625233698...|0.005846553661280072|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02538044852097...|-0.01115630564901936| -0.0984615561306473|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
#
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |        gt| model|              avg(x)|              avg(y)|              avg(z)|   avg(Arrival_Time)|  avg(Creation_Time)|        avg(Index)|              avg(x)|              avg(y)|              avg(z)|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+
# |      bike|nexus4|0.022510255124868785|-0.00898604823548...|-0.08336229972395504|1.424751134745484...|1.424752130275329...|326446.76449521456|0.022510255124868785|-0.00898604823548...|-0.08336229972395522|
# |      walk|nexus4|-0.00317765395921...|0.003289352996140...|0.002783577999142...|1.424746413916932E12|1.424747339095197...|149758.01792898812|-0.00317765395921...|0.003289352996140111|0.002783577999142...|
# |stairsdown|nexus4|0.024677638188492126|-0.03637329947153841| 0.12758820974660406|1.424744584991354...|1.424745492172551...| 230441.0154125436|0.024677638188491943|-0.03637329947153...|  0.1275882097466041|
# |       sit|nexus4|-5.02209146083024...| 3.79996281616075E-4|-2.52092116718567...|1.424741205198713E12|1.424742115477402...| 74569.19935552005|-5.02209146083022...|3.799962816160732...|-2.52092116718563...|
# |     stand|nexus4|-3.85281971657784...|4.911896808133751E-4|3.596050619546675...|1.424743639239765...|1.424744584280178...| 31323.20606663934|-3.85281971657783...|4.911896808133742E-4|3.596050619546695E-5|
# |      null|nexus4|-0.00551275851715...|-6.49222625233698...|0.005846553661280072|1.424749015628151...|1.424749931978247...|219244.12675876592|-0.00551275851715...|-6.49222625233695...|0.005846553661280067|
# |  stairsup|nexus4|-0.02538044852097...|-0.01115630564901936| -0.0984615561306473|1.424745998175379E12|1.424746914183747...|227953.55777019486|-0.02538044852097...|-0.01115630564901...| -0.0984615561306472|
# +----------+------+--------------------+--------------------+--------------------+--------------------+--------------------+------------------+--------------------+--------------------+--------------------+

# %%
# Stop the spark context
spark.stop()
